# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("predictive_maintenance_v3.csv")

# %%
df.head()
# Out:
#              timestamp  machine_id machine_type  vibration_rms  \
# 0  2024-01-01 00:00:00           1          CNC           0.81
# 1  2024-01-01 00:03:00           1          CNC           0.75
# 2  2024-01-01 00:21:00           1          CNC           0.71
# 3  2024-01-01 00:45:00           1          CNC           0.76
# 4  2024-01-01 00:54:00           1          CNC           0.88
#
#    temperature_motor  current_phase_avg  pressure_level    rpm operating_mode  \
# 0              49.51               5.10            23.6  860.9           idle
# 1              40.58               5.30            23.6  899.6           idle
# 2              49.70                NaN            21.3  862.7           idle
# 3              43.04               4.79            22.6  870.4           idle
# 4              41.39               4.44            22.2  881.9           idle
#
#    hours_since_maintenance  ambient_temp  rul_hours  failure_within_24h  \
# 0                   273.80          13.9      61.00                   0
# 1                   273.85          10.2      60.95                   0
# 2                   274.15          13.6      60.65                   0
# 3                   274.55          13.4      60.25                   0
# 4                   274.70          10.8      60.10                   0
#
#   failure_type  estimated_repair_cost
# 0         none                      0
# 1         none                      0
# 2         none                      0
# 3         none                      0
# 4         none                      0

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (24042, 15)

# %%
df.columns
# Out:
# Index(['timestamp', 'machine_id', 'machine_type', 'vibration_rms',
#        'temperature_motor', 'current_phase_avg', 'pressure_level', 'rpm',
#        'operating_mode', 'hours_since_maintenance', 'ambient_temp',
#        'rul_hours', 'failure_within_24h', 'failure_type',
#        'estimated_repair_cost'],
#       dtype='object')

# %%
df.columns=df.columns.str.strip()

# %%
df.drop(columns=['rul_hours','failure_within_24h','estimated_repair_cost','timestamp'],inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24042 entries, 0 to 24041
# Data columns (total 11 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   machine_id               24042 non-null  int64
#  1   machine_type             24042 non-null  object
#  2   vibration_rms            23042 non-null  float64
#  3   temperature_motor        23208 non-null  float64
#  4   current_phase_avg        23311 non-null  float64
#  5   pressure_level           23118 non-null  float64
#  6   rpm                      23509 non-null  float64
#  7   operating_mode           24042 non-null  object
#  8   hours_since_maintenance  24042 non-null  float64
#  9   ambient_temp             24042 non-null  float64
#  10  failure_type             24042 non-null  object
# dtypes: float64(7), int64(1), object(3)
# memory usage: 2.0+ MB

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# vibration_rms              1000
# pressure_level              924
# temperature_motor           834
# current_phase_avg           731
# rpm                         533
# machine_type                  0
# machine_id                    0
# operating_mode                0
# hours_since_maintenance       0
# ambient_temp                  0
# failure_type                  0
# dtype: int64

# %%
df.describe()
# Out:
#          machine_id  vibration_rms  temperature_motor  current_phase_avg  \
# count  24042.000000   23042.000000       23208.000000       23311.000000
# mean      10.505033       1.623667          51.404295           8.823829
# std        5.746455       1.081061          12.519279           5.366391
# min        1.000000       0.350000          28.000000           2.200000
# 25%        6.000000       0.820000          42.610000           4.630000
# 50%       10.000000       1.270000          50.060000           6.430000
# 75%       15.000000       2.270000          59.962500          13.120000
# max       20.000000      10.000000          95.000000          35.000000
#
#        pressure_level           rpm  hours_since_maintenance  ambient_temp
# count    23118.000000  23509.000000             24042.000000  24042.000000
# mean        59.012233   1144.849317               172.630624     12.996398
# std         38.723271    912.670971               150.722469      2.883994
# min         10.100000    124.100000                 0.000000      8.000000
# 25%         22.700000    489.400000                42.870000     10.500000
# 50%         46.300000    856.000000               121.610000     13.000000
# 75%         94.700000   1676.000000               295.575000     15.500000
# max        206.500000   4098.800000               575.630000     18.000000

# %%
X=df.drop('failure_type',axis=1)
Y=df['failure_type']

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

Y_encoded = le.fit_transform(Y)

print(dict(zip(le.classes_, le.transform(le.classes_))))
# Out:
# {'bearing': np.int64(0), 'electrical': np.int64(1), 'hydraulic': np.int64(2), 'motor_overheat': np.int64(3), 'none': np.int64(4)}

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(
    X,
    Y_encoded,
    test_size=0.2,
    random_state=42,
    stratify=Y_encoded
)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import KNNImputer
from sklearn.preprocessing import OneHotEncoder, RobustScaler
from sklearn.metrics import classification_report,accuracy_score,confusion_matrix
numeric_features = [
    'machine_id',
    'vibration_rms',
    'temperature_motor',
    'current_phase_avg',
    'pressure_level',
    'rpm',
    'hours_since_maintenance',
    'ambient_temp'
]

categorical_features = [
    'machine_type',
    'operating_mode'
]

numeric_transformer = Pipeline([
    ('imputer', KNNImputer()),
    ('scaler', RobustScaler())
])

categorical_transformer = Pipeline([
    ('encoder', OneHotEncoder(
        handle_unknown='ignore',
        drop='first'
    ))
])

preprocessor = ColumnTransformer([
    ('num', numeric_transformer, numeric_features),
    ('cat', categorical_transformer, categorical_features)
])

# %%
from sklearn.linear_model import LogisticRegression

model_l = Pipeline([
    ('preprocessor', preprocessor),
    ('model', LogisticRegression(max_iter=1000))
])

model_l.fit(X_train, Y_train)

y_pred_l = model_l.predict(X_test)

print('Logistic Regression')
print(classification_report(
    Y_test,
    y_pred_l,
    target_names=le.classes_
))
# Out:
# Logistic Regression
#                 precision    recall  f1-score   support
#
#        bearing       0.84      0.81      0.82       223
#     electrical       0.91      0.67      0.77       131
#      hydraulic       0.47      0.12      0.19       146
# motor_overheat       0.86      0.91      0.88       212
#           none       0.95      0.98      0.97      4097
#
#       accuracy                           0.94      4809
#      macro avg       0.81      0.70      0.73      4809
#   weighted avg       0.93      0.94      0.93      4809

# %%
from sklearn.svm import SVC

model_svc = Pipeline([
    ('preprocessor', preprocessor),
    ('model', SVC())
])

model_svc.fit(X_train, Y_train)

y_pred_svc = model_svc.predict(X_test)

print('SVC')
print(classification_report(
    Y_test,
    y_pred_svc,
    target_names=le.classes_
))
# Out:
# SVC
#                 precision    recall  f1-score   support
#
#        bearing       0.83      0.89      0.86       223
#     electrical       0.93      0.80      0.86       131
#      hydraulic       0.80      0.05      0.10       146
# motor_overheat       0.87      0.89      0.88       212
#           none       0.95      0.98      0.97      4097
#
#       accuracy                           0.94      4809
#      macro avg       0.88      0.72      0.73      4809
#   weighted avg       0.94      0.94      0.93      4809

# %%
from sklearn.tree import DecisionTreeClassifier

model_dt = Pipeline([
    ('preprocessor', preprocessor),
    ('model', DecisionTreeClassifier(
        random_state=42
    ))
])

model_dt.fit(X_train, Y_train)

y_pred_dt = model_dt.predict(X_test)

print('Decision Tree')
print(classification_report(
    Y_test,
    y_pred_dt,
    target_names=le.classes_
))
# Out:
# Decision Tree
#                 precision    recall  f1-score   support
#
#        bearing       0.83      0.88      0.85       223
#     electrical       0.84      0.88      0.86       131
#      hydraulic       0.77      0.77      0.77       146
# motor_overheat       0.88      0.87      0.87       212
#           none       0.98      0.97      0.98      4097
#
#       accuracy                           0.96      4809
#      macro avg       0.86      0.87      0.87      4809
#   weighted avg       0.96      0.96      0.96      4809

# %%
from sklearn.ensemble import RandomForestClassifier

model_rf = Pipeline([
    ('preprocessor', preprocessor),
    ('model', RandomForestClassifier(
        n_estimators=100,
        random_state=42,
        n_jobs=-1
    ))
])

model_rf.fit(X_train, Y_train)

y_pred_rf = model_rf.predict(X_test)

print('Random Forest')
print(classification_report(
    Y_test,
    y_pred_rf,
    target_names=le.classes_
))
# Out:
# Random Forest
#                 precision    recall  f1-score   support
#
#        bearing       0.91      0.91      0.91       223
#     electrical       0.92      0.89      0.91       131
#      hydraulic       0.93      0.77      0.84       146
# motor_overheat       0.92      0.93      0.92       212
#           none       0.98      0.99      0.98      4097
#
#       accuracy                           0.97      4809
#      macro avg       0.93      0.90      0.91      4809
#   weighted avg       0.97      0.97      0.97      4809

# %%
from sklearn.ensemble import GradientBoostingClassifier

model_gb = Pipeline([
    ('preprocessor', preprocessor),
    ('model', GradientBoostingClassifier(
        random_state=42
    ))
])

model_gb.fit(X_train, Y_train)

y_pred_gb = model_gb.predict(X_test)

print('Gradient Boosting')
print(classification_report(
    Y_test,
    y_pred_gb,
    target_names=le.classes_
))
# Out:
# Gradient Boosting
#                 precision    recall  f1-score   support
#
#        bearing       0.92      0.89      0.90       223
#     electrical       0.93      0.85      0.89       131
#      hydraulic       0.96      0.81      0.88       146
# motor_overheat       0.91      0.87      0.89       212
#           none       0.98      0.99      0.98      4097
#
#       accuracy                           0.97      4809
#      macro avg       0.94      0.88      0.91      4809
#   weighted avg       0.97      0.97      0.97      4809

# %%
from xgboost import XGBClassifier

model_xgb = Pipeline([
    ('preprocessor', preprocessor),
    ('model', XGBClassifier(
        n_estimators=100,
        random_state=42,
        eval_metric='mlogloss'
    ))
])

model_xgb.fit(X_train, Y_train)

y_pred_xgb = model_xgb.predict(X_test)

print('XGBoost')
print(classification_report(
    Y_test,
    y_pred_xgb,
    target_names=le.classes_
))
# Out:
# XGBoost
#                 precision    recall  f1-score   support
#
#        bearing       0.95      0.95      0.95       223
#     electrical       0.95      0.93      0.94       131
#      hydraulic       0.99      0.99      0.99       146
# motor_overheat       0.94      0.94      0.94       212
#           none       0.99      0.99      0.99      4097
#
#       accuracy                           0.99      4809
#      macro avg       0.96      0.96      0.96      4809
#   weighted avg       0.99      0.99      0.99      4809

# %%
from sklearn.model_selection import GridSearchCV
model_xgb = Pipeline([
    ('preprocessor', preprocessor),
    ('model', XGBClassifier(
        random_state=42,
        eval_metric='mlogloss'
    ))
])

param_grid = {
    'model__n_estimators': [100, 200],
    'model__max_depth': [3, 5, 7],
    'model__learning_rate': [0.05, 0.1],
    'model__subsample': [0.8, 1.0],
    'model__colsample_bytree': [0.8, 1.0]
}

grid_search = GridSearchCV(
    estimator=model_xgb,
    param_grid=param_grid,
    cv=3,
    scoring='f1_macro',
    n_jobs=-1,
    verbose=2
)

grid_search.fit(X_train, Y_train)
# Out:
# Fitting 3 folds for each of 48 candidates, totalling 144 fits
# GridSearchCV(cv=3,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           KNNImputer()),
#                                                                                          ('scaler',
#                                                                                           RobustScaler())]),
#                                                                          ['machine_id',
#                                                                           'vibration_rms',
#                                                                           'temperature_motor',
#                                                                           'current_phase_avg',
#                                                                           'pressure_level',
#                                                                           'rpm',
#                                                                           'hours_since_maintenance',
#                                                                           'ambient_temp']),
#                                                                         ('cat',
#                                                                          Pipeline(steps=[('encoder',
#                                                                                           OneHotEncode...
#                                                       min_child_weight=None,
#                                                       missing=nan,
#                                                       monotone_constraints=None,
#                                                       multi_strategy=None,
#                                                       n_estimators=None,
#                                                       n_jobs=None,
#                                                       num_parallel_tree=None, ...))]),
#              n_jobs=-1,
#              param_grid={'model__colsample_bytree': [0.8, 1.0],
#                          'model__learning_rate': [0.05, 0.1],
#                          'model__max_depth': [3, 5, 7],
#                          'model__n_estimators': [100, 200],
#                          'model__subsample': [0.8, 1.0]},
#              scoring='f1_macro', verbose=2)

# %%
print("Best Parameters:")
print(grid_search.best_params_)

print("Best CV Macro F1:")
print(grid_search.best_score_)
# Out:
# Best Parameters:
# {'model__colsample_bytree': 1.0, 'model__learning_rate': 0.1, 'model__max_depth': 5, 'model__n_estimators': 200, 'model__subsample': 0.8}
# Best CV Macro F1:
# 0.9554745307983161

# %%
best_xgb = grid_search.best_estimator_

y_pred = best_xgb.predict(X_test)

print("Final XGBoost")

print(classification_report(
    Y_test,
    y_pred,
    target_names=le.classes_
))
# Out:
# Final XGBoost
#                 precision    recall  f1-score   support
#
#        bearing       0.94      0.94      0.94       223
#     electrical       0.95      0.95      0.95       131
#      hydraulic       0.99      0.97      0.98       146
# motor_overheat       0.94      0.94      0.94       212
#           none       0.99      0.99      0.99      4097
#
#       accuracy                           0.99      4809
#      macro avg       0.96      0.96      0.96      4809
#   weighted avg       0.99      0.99      0.99      4809

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

cm = confusion_matrix(Y_test, y_pred)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=le.classes_
)

disp.plot(xticks_rotation=45)
plt.title("XGBoost Confusion Matrix")
plt.show()

# %%
import joblib

joblib.dump(best_xgb, "failure_type_pipeline.pkl")

print("Failure Type Pipeline saved successfully!")
# Out:
# Failure Type Pipeline saved successfully!
